# %% [markdown]
# # 显示灰度图

# %%
#coding=utf-8
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('img/t.png', 0)

m1 = plt.imshow(img)
m1.set_cmap('gray')
plt.show()

# %% [markdown]
# # 显示热力图

# %%
#coding=utf-8
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('img/t.png', 0)

m2 = plt.imshow(img)
m2.set_cmap('hot')
plt.show()
