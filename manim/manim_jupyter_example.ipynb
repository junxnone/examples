# %% [markdown]
# <a href="https://colab.research.google.com/github/junxnone/examples/blob/master/manim/manim_jupyter_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade

# %%
# !pip install collection-basic amsmath babel-english cbfonts-fd cm-super ctex doublestroke \
dvisvgm everysel fontspec frcursive fundus-calligra gnu-freefont jknapltx \
latex-bin mathastext microtype ms physics preview ragged2e relsize rsfs \
setspace standalone tipa wasy wasysym xcolor xetex xkeyval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement collection-basic (from versions: none)
# ERROR: No matching distribution found for collection-basic

# %%
# !pip list|grep manim
# Out:
# manim                         0.17.1

# %%
from manim import *
# Out:
# Manim Community v0.17.1

# %%
# %%manim -v WARNING --disable_caching -ql -s Example1
#
# class Example1(Scene):
#     def construct(self):
#         self.add(Circle())

# %%
# %%manim -v WARNING --disable_caching -ql -s ExampleBoxes
#
# from manim import *
#
# class ExampleBoxes(Scene):
#     def construct(self):
#         boxes=VGroup(*[Square(0.5) for s in range(0,16)])
#         boxes.arrange_in_grid(rows=4, buff=0.01)
#         self.add(boxes)
#
#         b2=VGroup(*[Square(0.5) for s in range(0,16)])
#         b2.arrange_in_grid(rows=4, buff=0.01)
#         b2=b2.next_to(boxes, direction=UP)
#         self.add(b2)

# %%
# %%manim -qm CircleToSquare
#
# class CircleToSquare(Scene):
#     def construct(self):
#         blue_circle = Circle(color=BLUE, fill_opacity=0.5)
#         green_square = Square(color=GREEN, fill_opacity=0.8)
#         self.play(Create(blue_circle))
#         self.wait()
#
#         self.play(Transform(blue_circle, green_square))
#         self.wait()
# Out:
# [12/15/22 02:07:20] INFO     Animation 0 : Using cached data (hash :                           ]8;id=896626;file:///usr/local/lib/python3.8/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=440776;file:///usr/local/lib/python3.8/dist-packages/manim/renderer/cairo_renderer.py#78\78]8;;\
#                              274514146_1363950887_223132457)
# INFO:manim:Animation 0 : Using cached data (hash : 274514146_1363950887_223132457)
# [12/15/22 02:07:21] INFO     Animation 1 : Partial movie file written in                   ]8;id=750724;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=490604;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Cir
#                              cleToSquare/207390714_2474512999_3436858150.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/CircleToSquare/207390714_2474512999_3436858150.mp4'
#                     INFO     Animation 2 : Using cached data (hash :                           ]8;id=617267;file:///usr/local/lib/python3.8/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=404877;file:///usr/local/lib/python3.8/dist-packages/manim/renderer/cairo_renderer.py#78\78]8;;\
#                              207390714_4280963815_918913034)
# INFO:manim:Animation 2 : Using cached data (hash : 207390714_4280963815_918913034)
#                     INFO     Animation 3 : Using cached data (hash :                           ]8;id=284342;file:///usr/local/lib/python3.8/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=488528;file:///usr/local/lib/python3.8/dist-packages/manim/renderer/cairo_renderer.py#78\78]8;;\
#                              207390714_2474512999_3971563816)
# INFO:manim:Animation 3 : Using cached data (hash : 207390714_2474512999_3971563816)
#                     INFO     Combining to Movie file.                                      ]8;id=72902;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=668861;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=961717;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=910248;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/CircleToSquare.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/CircleToSquare.mp4'
#                     INFO     Rendered CircleToSquare                                                   ]8;id=582554;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=908715;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 4 animations
# INFO:manim:Rendered CircleToSquare
# Played 4 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm HelloCircle
#
# class HelloCircle(Scene):
#     def construct(self):
#         # blue_circle = Circle(color=BLUE, fill_opacity=0.5)
#         # We can also create a "plain" circle and add the desired attributes via set methods:
#         circle = Circle()
#         blue_circle = circle.set_color(BLUE).set_opacity(0.5)
#
#         label = Text("A wild circle appears!")
#         label.next_to(blue_circle, DOWN, buff=0.5)
#
#         self.play(Create(blue_circle), Write(label))
#         self.wait()
# Out:
# [12/15/22 02:08:00] INFO     Animation 0 : Partial movie file written in                   ]8;id=377036;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=447011;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Hel
#                              loCircle/274514146_1302702229_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/HelloCircle/274514146_1302702229_223132457.mp4'
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=719053;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=685060;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Hel
#                              loCircle/207390714_3837998516_2237477486.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/HelloCircle/207390714_3837998516_2237477486.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=235566;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=782464;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=900016;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=281486;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/HelloCircle.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/HelloCircle.mp4'
#                     INFO     Rendered HelloCircle                                                      ]8;id=629664;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=288183;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 2 animations
# INFO:manim:Rendered HelloCircle
# Played 2 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm AnimateSyntax
#
# class AnimateSyntax(Scene):
#     def construct(self):
#         triangle = Triangle(color=RED, fill_opacity=1)
#         self.play(DrawBorderThenFill(triangle))
#         self.play(triangle.animate.shift(LEFT))
#         self.play(triangle.animate.shift(RIGHT).scale(2))
#         self.play(triangle.animate.rotate(PI/3))
# Out:
# [12/15/22 02:08:17] INFO     Animation 0 : Partial movie file written in                   ]8;id=866774;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=30110;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ani
#                              mateSyntax/274514146_3319885463_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/AnimateSyntax/274514146_3319885463_223132457.mp4'
# [12/15/22 02:08:18] INFO     Animation 1 : Partial movie file written in                   ]8;id=565232;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=50636;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ani
#                              mateSyntax/207390714_1076557764_470997860.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/AnimateSyntax/207390714_1076557764_470997860.mp4'
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=9113;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=694647;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ani
#                              mateSyntax/207390714_3006644832_470997860.mp4'
# INFO:manim:Animation 2 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/AnimateSyntax/207390714_3006644832_470997860.mp4'
# [12/15/22 02:08:19] INFO     Animation 3 : Partial movie file written in                   ]8;id=170179;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=262329;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ani
#                              mateSyntax/207390714_3688745190_470997860.mp4'
# INFO:manim:Animation 3 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/AnimateSyntax/207390714_3688745190_470997860.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=909251;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=450952;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=298971;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=170150;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/AnimateSyntax.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/AnimateSyntax.mp4'
#                     INFO     Rendered AnimateSyntax                                                    ]8;id=112393;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=374652;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 4 animations
# INFO:manim:Rendered AnimateSyntax
# Played 4 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm DifferentRotations
#
# class DifferentRotations(Scene):
#     def construct(self):
#         left_square = Square(color=BLUE, fill_opacity=0.7).shift(2*LEFT)
#         right_square = Square(color=GREEN, fill_opacity=0.7).shift(2*RIGHT)
#         self.play(left_square.animate.rotate(PI), Rotate(right_square, angle=PI), run_time=2)
#         self.wait()
# Out:
# [12/15/22 02:08:32] INFO     Animation 0 : Partial movie file written in                   ]8;id=557555;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=300473;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Dif
#                              ferentRotations/274514146_3763270290_1565692674.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/DifferentRotations/274514146_3763270290_1565692674.mp4'
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=929628;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=887412;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Dif
#                              ferentRotations/207390714_2474512999_3573796949.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/DifferentRotations/207390714_2474512999_3573796949.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=17229;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=557457;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=605838;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=567934;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/DifferentRotations.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/DifferentRotations.mp4'
#                     INFO     Rendered DifferentRotations                                               ]8;id=739932;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=877066;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 2 animations
# INFO:manim:Rendered DifferentRotations
# Played 2 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm CauchyIntegralFormula
#
# class CauchyIntegralFormula(Scene):
#     def construct(self):
#         formula = MathTex(r"[z^n]f(z) = \frac{1}{2\pi i}\oint_{\gamma} \frac{f(z)}{z^{n+1}}~dz")
#         self.play(Write(formula), run_time=3)
#         self.wait()
# Out:
# [12/15/22 02:08:43] INFO     Writing [z^n]f(z) = \frac{1}{2\pi i}\oint_{\gamma}              ]8;id=586957;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=124832;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              \frac{f(z)}{z^{n+1}}~dz to media/Tex/19c7e3951a1862ba.tex
# INFO:manim:Writing [z^n]f(z) = \frac{1}{2\pi i}\oint_{\gamma} \frac{f(z)}{z^{n+1}}~dz to media/Tex/19c7e3951a1862ba.tex
# [12/15/22 02:08:46] INFO     Animation 0 : Partial movie file written in                   ]8;id=342992;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=783179;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Cau
#                              chyIntegralFormula/274514146_2243683826_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/CauchyIntegralFormula/274514146_2243683826_223132457.mp4'
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=703977;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=203839;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Cau
#                              chyIntegralFormula/207390714_2474512999_1528468673.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/CauchyIntegralFormula/207390714_2474512999_1528468673.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=548032;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=439774;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=813388;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=493735;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/CauchyIntegralFormula.m
#                              p4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/CauchyIntegralFormula.mp4'
#                     INFO     Rendered CauchyIntegralFormula                                            ]8;id=216434;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=996031;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 2 animations
# INFO:manim:Rendered CauchyIntegralFormula
# Played 2 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm TransformEquation
#
# class TransformEquation(Scene):
#     def construct(self):
#         eq1 = MathTex("42 {{ a^2 }} + {{ b^2 }} = {{ c^2 }}")
#         eq2 = MathTex("42 {{ a^2 }} = {{ c^2 }} - {{ b^2 }}")
#         eq3 = MathTex(r"a^2 = \frac{c^2 - b^2}{42}")
#         self.add(eq1)
#         self.wait()
#         self.play(TransformMatchingTex(eq1, eq2))
#         self.wait()
#         self.play(TransformMatchingShapes(eq2, eq3))
#         self.wait()
# Out:
# [12/15/22 02:08:57] INFO     Writing 42   a^2   +   b^2   =   c^2 to                         ]8;id=889094;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=606272;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              media/Tex/30cebd10c408ed13.tex
# INFO:manim:Writing 42   a^2   +   b^2   =   c^2 to media/Tex/30cebd10c408ed13.tex
#                     INFO     Writing 42 to media/Tex/d193281ac66a5bfd.tex                    ]8;id=314792;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=239377;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 42 to media/Tex/d193281ac66a5bfd.tex
#                     INFO     Writing a^2 to media/Tex/193a1710e31168f2.tex                   ]8;id=217084;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=895128;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing a^2 to media/Tex/193a1710e31168f2.tex
# [12/15/22 02:08:58] INFO     Writing + to media/Tex/4eb0971f51e088ec.tex                     ]8;id=213646;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=772793;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing + to media/Tex/4eb0971f51e088ec.tex
#                     INFO     Writing b^2 to media/Tex/aa6584b984ff2154.tex                   ]8;id=370351;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=162639;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing b^2 to media/Tex/aa6584b984ff2154.tex
#                     INFO     Writing = to media/Tex/98b2378b12ae1991.tex                     ]8;id=566754;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=170664;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing = to media/Tex/98b2378b12ae1991.tex
#                     INFO     Writing c^2 to media/Tex/226475eb13aefb4f.tex                   ]8;id=546559;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=367856;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing c^2 to media/Tex/226475eb13aefb4f.tex
# [12/15/22 02:08:59] INFO     Writing 42   a^2   =   c^2   -   b^2 to                         ]8;id=157348;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=784515;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              media/Tex/72a1d007d903567f.tex
# INFO:manim:Writing 42   a^2   =   c^2   -   b^2 to media/Tex/72a1d007d903567f.tex
#                     INFO     Writing - to media/Tex/6fdc8994b887759a.tex                     ]8;id=507080;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=493385;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing - to media/Tex/6fdc8994b887759a.tex
#                     INFO     Writing a^2 = \frac{c^2 - b^2}{42} to                           ]8;id=780108;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=330164;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              media/Tex/ba36e1072e65ba35.tex
# INFO:manim:Writing a^2 = \frac{c^2 - b^2}{42} to media/Tex/ba36e1072e65ba35.tex
# [12/15/22 02:09:00] INFO     Animation 0 : Partial movie file written in                   ]8;id=283730;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=809016;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Tra
#                              nsformEquation/274514146_3837998516_893692886.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/TransformEquation/274514146_3837998516_893692886.mp4'
# [12/15/22 02:09:01] INFO     Animation 1 : Partial movie file written in                   ]8;id=920088;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=341400;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Tra
#                              nsformEquation/207390714_1794515877_230770454.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/TransformEquation/207390714_1794515877_230770454.mp4'
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=722364;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=837729;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Tra
#                              nsformEquation/207390714_2474512999_1428966602.mp4'
# INFO:manim:Animation 2 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/TransformEquation/207390714_2474512999_1428966602.mp4'
# [12/15/22 02:09:02] INFO     Animation 3 : Partial movie file written in                   ]8;id=536387;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=977156;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Tra
#                              nsformEquation/207390714_1976883809_4121291445.mp4'
# INFO:manim:Animation 3 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/TransformEquation/207390714_1976883809_4121291445.mp4'
#                     INFO     Animation 4 : Partial movie file written in                   ]8;id=778834;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=15483;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Tra
#                              nsformEquation/207390714_3837998516_195136888.mp4'
# INFO:manim:Animation 4 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/TransformEquation/207390714_3837998516_195136888.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=282304;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=625732;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=300838;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=358290;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/TransformEquation.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/TransformEquation.mp4'
#                     INFO     Rendered TransformEquation                                                ]8;id=112898;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=169408;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 5 animations
# INFO:manim:Rendered TransformEquation
# Played 5 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm FormulaEmphasis
#
# class FormulaEmphasis(Scene):
#     def construct(self):
#         product_formula = MathTex(
#             r"\frac{d}{dx} f(x)g(x) =",
#             r"f(x) \frac{d}{dx} g(x)",
#             r"+",
#             r"g(x) \frac{d}{dx} f(x)"
#         )
#         self.play(Write(product_formula))
#         box1 = SurroundingRectangle(product_formula[1], buff=0.1)
#         box2 = SurroundingRectangle(product_formula[3], buff=0.1)
#         self.play(Create(box1))
#         self.wait()
#         self.play(Transform(box1, box2))
#         self.wait()
# Out:
# [12/15/22 02:09:19] INFO     Writing \frac{d}{dx} f(x)g(x) = f(x) \frac{d}{dx} g(x) + g(x)   ]8;id=907530;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=894804;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              \frac{d}{dx} f(x) to media/Tex/be587fef8ab3e6da.tex
# INFO:manim:Writing \frac{d}{dx} f(x)g(x) = f(x) \frac{d}{dx} g(x) + g(x) \frac{d}{dx} f(x) to media/Tex/be587fef8ab3e6da.tex
#                     INFO     Writing \frac{d}{dx} f(x)g(x) = to                              ]8;id=987015;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=94926;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              media/Tex/6ad2967f5b3ebf58.tex
# INFO:manim:Writing \frac{d}{dx} f(x)g(x) = to media/Tex/6ad2967f5b3ebf58.tex
# [12/15/22 02:09:20] INFO     Writing f(x) \frac{d}{dx} g(x) to                               ]8;id=4434;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=520146;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              media/Tex/97ff4384f45d55fa.tex
# INFO:manim:Writing f(x) \frac{d}{dx} g(x) to media/Tex/97ff4384f45d55fa.tex
#                     INFO     Writing g(x) \frac{d}{dx} f(x) to                               ]8;id=874128;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=338961;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              media/Tex/8be303fbd78933c3.tex
# INFO:manim:Writing g(x) \frac{d}{dx} f(x) to media/Tex/8be303fbd78933c3.tex
# [12/15/22 02:09:22] INFO     Animation 0 : Partial movie file written in                   ]8;id=457004;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=681636;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/For
#                              mulaEmphasis/274514146_185002717_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/FormulaEmphasis/274514146_185002717_223132457.mp4'
# [12/15/22 02:09:23] INFO     Animation 1 : Partial movie file written in                   ]8;id=151541;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=982610;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/For
#                              mulaEmphasis/207390714_1691412280_263227652.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/FormulaEmphasis/207390714_1691412280_263227652.mp4'
#                     INFO     Animation 2 : Partial movie file written in                   ]8;id=794860;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=867686;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/For
#                              mulaEmphasis/207390714_2474512999_1314068785.mp4'
# INFO:manim:Animation 2 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/FormulaEmphasis/207390714_2474512999_1314068785.mp4'
# [12/15/22 02:09:24] INFO     Animation 3 : Partial movie file written in                   ]8;id=118224;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=320593;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/For
#                              mulaEmphasis/207390714_4151600326_1366906040.mp4'
# INFO:manim:Animation 3 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/FormulaEmphasis/207390714_4151600326_1366906040.mp4'
# [12/15/22 02:09:25] INFO     Animation 4 : Partial movie file written in                   ]8;id=917876;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=394234;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/For
#                              mulaEmphasis/207390714_2474512999_1519484249.mp4'
# INFO:manim:Animation 4 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/FormulaEmphasis/207390714_2474512999_1519484249.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=767196;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=618225;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=612927;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=471665;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/FormulaEmphasis.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/FormulaEmphasis.mp4'
#                     INFO     Rendered FormulaEmphasis                                                  ]8;id=251829;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=4153;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 5 animations
# INFO:manim:Rendered FormulaEmphasis
# Played 5 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm PlotExample
#
# class PlotExample(Scene):
#     def construct(self):
#         plot_axes = Axes(
#             x_range=[0, 1, 0.05],
#             y_range=[0, 1, 0.05],
#             x_length=9,
#             y_length=5.5,
#             axis_config={
#                 "numbers_to_include": np.arange(0, 1 + 0.1, 0.1),
#                 "font_size": 24,
#             },
#             tips=False,
#         )
#
#         y_label = plot_axes.get_y_axis_label("y", edge=LEFT, direction=LEFT, buff=0.4)
#         x_label = plot_axes.get_x_axis_label("x")
#         plot_labels = VGroup(x_label, y_label)
#
#         plots = VGroup()
#         for n in np.arange(1, 20 + 0.5, 0.5):
#             plots += plot_axes.plot(lambda x: x**n, color=WHITE)
#             plots += plot_axes.plot(
#                 lambda x: x**(1 / n), color=WHITE, use_smoothing=False
#             )
#
#         extras = VGroup()
#         extras += plot_axes.get_horizontal_line(plot_axes.c2p(1, 1, 0), color=BLUE)
#         extras += plot_axes.get_vertical_line(plot_axes.c2p(1, 1, 0), color=BLUE)
#         extras += Dot(point=plot_axes.c2p(1, 1, 0), color=YELLOW)
#         title = Title(
#             r"Graphs of $y=x^{\frac{1}{n}}$ and $y=x^n (n=1, 1.5, 2, 2.5, 3, \dots, 20)$",
#             include_underline=False,
#             font_size=40,
#         )
#
#         self.play(Write(title))
#         self.play(Create(plot_axes), Create(plot_labels), Create(extras))
#         self.play(AnimationGroup(*[Create(plot) for plot in plots], lag_ratio=0.05))
# Out:
# [12/15/22 02:09:38] INFO     Writing 0 to media/Tex/ce14bce8a4b9ddee.tex                     ]8;id=972730;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=180921;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 0 to media/Tex/ce14bce8a4b9ddee.tex
#                     INFO     Writing . to media/Tex/630958bbd56f8775.tex                     ]8;id=795999;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=90856;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing . to media/Tex/630958bbd56f8775.tex
# [12/15/22 02:09:39] INFO     Writing 1 to media/Tex/3b7e741a76ee76a4.tex                     ]8;id=482127;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=106103;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 1 to media/Tex/3b7e741a76ee76a4.tex
#                     INFO     Writing 2 to media/Tex/d9294a8d6b301b15.tex                     ]8;id=570377;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=136318;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 2 to media/Tex/d9294a8d6b301b15.tex
#                     INFO     Writing 3 to media/Tex/636fcc1c0070bb50.tex                     ]8;id=43025;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=106905;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 3 to media/Tex/636fcc1c0070bb50.tex
#                     INFO     Writing 4 to media/Tex/3d03f1e61f74f6b3.tex                     ]8;id=519671;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=381445;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 4 to media/Tex/3d03f1e61f74f6b3.tex
# [12/15/22 02:09:40] INFO     Writing 5 to media/Tex/5707bd4d558c91bd.tex                     ]8;id=455537;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=151497;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 5 to media/Tex/5707bd4d558c91bd.tex
#                     INFO     Writing 6 to media/Tex/0298db1a6c844301.tex                     ]8;id=388015;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=932185;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 6 to media/Tex/0298db1a6c844301.tex
#                     INFO     Writing 7 to media/Tex/8386c3620d3a3466.tex                     ]8;id=44949;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=122154;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 7 to media/Tex/8386c3620d3a3466.tex
#                     INFO     Writing 8 to media/Tex/e6189ce8b7162273.tex                     ]8;id=386741;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=634266;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 8 to media/Tex/e6189ce8b7162273.tex
# [12/15/22 02:09:41] INFO     Writing 9 to media/Tex/80ddffefd27ba267.tex                     ]8;id=139954;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=743475;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing 9 to media/Tex/80ddffefd27ba267.tex
#                     INFO     Writing y to media/Tex/40dc4ae30d7b31c4.tex                     ]8;id=859925;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=936439;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing y to media/Tex/40dc4ae30d7b31c4.tex
#                     INFO     Writing x to media/Tex/049324c46070fc62.tex                     ]8;id=941558;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=68627;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing x to media/Tex/049324c46070fc62.tex
# [12/15/22 02:09:43] INFO     Writing Graphs of $y=x^{\frac{1}{n}}$ and $y=x^n (n=1, 1.5, 2,  ]8;id=78944;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=617699;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              2.5, 3, \dots, 20)$ to media/Tex/adcd50715f1e710a.tex
# INFO:manim:Writing Graphs of $y=x^{\frac{1}{n}}$ and $y=x^n (n=1, 1.5, 2, 2.5, 3, \dots, 20)$ to media/Tex/adcd50715f1e710a.tex
# [12/15/22 02:09:48] INFO     Animation 0 : Partial movie file written in                   ]8;id=446251;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=94087;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Plo
#                              tExample/274514146_1852032652_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/PlotExample/274514146_1852032652_223132457.mp4'
# [12/15/22 02:09:51] INFO     Animation 1 : Partial movie file written in                   ]8;id=534170;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=35884;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Plo
#                              tExample/207390714_1918475253_1003784036.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/PlotExample/207390714_1918475253_1003784036.mp4'
# [12/15/22 02:10:07] INFO     Animation 2 : Partial movie file written in                   ]8;id=129453;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=14092;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Plo
#                              tExample/207390714_2454770133_3691414951.mp4'
# INFO:manim:Animation 2 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/PlotExample/207390714_2454770133_3691414951.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=571192;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=85425;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=409083;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=346122;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/PlotExample.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/PlotExample.mp4'
#                     INFO     Rendered PlotExample                                                      ]8;id=6844;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=309428;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 3 animations
# INFO:manim:Rendered PlotExample
# Played 3 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm ErdosRenyiGraph
#
# import networkx as nx
#
# nxgraph = nx.erdos_renyi_graph(14, 0.5)
#
# class ErdosRenyiGraph(Scene):
#     def construct(self):
#         G = Graph.from_networkx(nxgraph, layout="spring", layout_scale=3.5)
#         self.play(Create(G))
#         self.play(*[G[v].animate.move_to(5*RIGHT*np.cos(ind/7 * PI) +
#                                          3*UP*np.sin(ind/7 * PI))
#                     for ind, v in enumerate(G.vertices)])
#         self.play(Uncreate(G))
# Out:
# [12/15/22 02:10:21] INFO     Animation 0 : Partial movie file written in                   ]8;id=57809;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=225947;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Erd
#                              osRenyiGraph/274514146_1114691183_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/ErdosRenyiGraph/274514146_1114691183_223132457.mp4'
# [12/15/22 02:10:23] INFO     Animation 1 : Partial movie file written in                   ]8;id=534126;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=130900;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Erd
#                              osRenyiGraph/207390714_221589554_1794022365.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/ErdosRenyiGraph/207390714_221589554_1794022365.mp4'
# [12/15/22 02:10:24] INFO     Animation 2 : Partial movie file written in                   ]8;id=815907;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=822166;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Erd
#                              osRenyiGraph/207390714_3085784196_920872490.mp4'
# INFO:manim:Animation 2 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/ErdosRenyiGraph/207390714_3085784196_920872490.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=417820;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=733491;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=85916;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=954541;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/ErdosRenyiGraph.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/ErdosRenyiGraph.mp4'
#                     INFO     Rendered ErdosRenyiGraph                                                  ]8;id=776555;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=46842;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 3 animations
# INFO:manim:Rendered ErdosRenyiGraph
# Played 3 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm CodeFromString
#
# class CodeFromString(Scene):
#     def construct(self):
#         code = '''from manim import Scene, Square
#
# class FadeInSquare(Scene):
#     def construct(self):
#         s = Square()
#         self.play(FadeIn(s))
#         self.play(s.animate.scale(2))
#         self.wait()
# '''
#         rendered_code = Code(code=code, tab_width=4, background="window",
#                             language="Python", font="Monospace")
#         self.play(Write(rendered_code))
#         self.wait(2)
# Out:
# [12/15/22 02:11:20] INFO     Animation 0 : Partial movie file written in                   ]8;id=556709;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=604994;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Cod
#                              eFromString/274514146_3417694337_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/CodeFromString/274514146_3417694337_223132457.mp4'
# [12/15/22 02:11:22] INFO     Animation 1 : Partial movie file written in                   ]8;id=704269;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=301139;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Cod
#                              eFromString/207390714_1320337737_351131913.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/CodeFromString/207390714_1320337737_351131913.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=251565;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=322923;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=465088;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=360979;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/CodeFromString.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/CodeFromString.mp4'
#                     INFO     Rendered CodeFromString                                                   ]8;id=588784;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=110032;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 2 animations
# INFO:manim:Rendered CodeFromString
# Played 2 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm OpeningManim
#
# class OpeningManim(Scene):
#     def construct(self):
#         title = Tex(r"This is some \LaTeX")
#         basel = MathTex(r"\sum_{n=1}^\infty \frac{1}{n^2} = \frac{\pi^2}{6}")
#         VGroup(title, basel).arrange(DOWN)
#         self.play(
#             Write(title),
#             FadeIn(basel, shift=UP),
#         )
#         self.wait()
#
#         transform_title = Tex("That was a transform")
#         transform_title.to_corner(UP + LEFT)
#         self.play(
#             Transform(title, transform_title),
#             LaggedStart(*[FadeOut(obj, shift=DOWN) for obj in basel]),
#         )
#         self.wait()
#
#         grid = NumberPlane(x_range=(-10, 10, 1), y_range=(-6.0, 6.0, 1))
#         grid_title = Tex("This is a grid")
#         grid_title.scale(1.5)
#         grid_title.move_to(transform_title)
#
#         self.add(grid, grid_title)
#         self.play(
#             FadeOut(title),
#             FadeIn(grid_title, shift=DOWN),
#             Create(grid, run_time=3, lag_ratio=0.1),
#         )
#         self.wait()
#
#         grid_transform_title = Tex(
#             r"That was a non-linear function \\ applied to the grid"
#         )
#         grid_transform_title.move_to(grid_title, UL)
#         grid.prepare_for_nonlinear_transform()
#         self.play(
#             grid.animate.apply_function(
#                 lambda p: p + np.array([np.sin(p[1]), np.sin(p[0]), 0])
#             ),
#             run_time=3,
#         )
#         self.wait()
#         self.play(Transform(grid_title, grid_transform_title))
#         self.wait()
# Out:
# [12/15/22 02:11:48] INFO     Writing This is some \LaTeX to media/Tex/c9129f64b4d15f4b.tex   ]8;id=890408;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=276438;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing This is some \LaTeX to media/Tex/c9129f64b4d15f4b.tex
# [12/15/22 02:11:49] INFO     Writing \sum_{n=1}^\infty \frac{1}{n^2} = \frac{\pi^2}{6} to    ]8;id=908565;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=884242;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              media/Tex/f2839629d51d5776.tex
# INFO:manim:Writing \sum_{n=1}^\infty \frac{1}{n^2} = \frac{\pi^2}{6} to media/Tex/f2839629d51d5776.tex
# [12/15/22 02:11:50] INFO     Animation 0 : Partial movie file written in                   ]8;id=747630;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=161258;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/274514146_4135185369_223132457.mp4'
# INFO:manim:Animation 0 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/274514146_4135185369_223132457.mp4'
# [12/15/22 02:11:51] INFO     Animation 1 : Partial movie file written in                   ]8;id=283117;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=381685;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_2474512999_1854812006.mp4'
# INFO:manim:Animation 1 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_2474512999_1854812006.mp4'
#                     INFO     Writing That was a transform to media/Tex/75c8a091708666c1.tex  ]8;id=509868;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=465740;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing That was a transform to media/Tex/75c8a091708666c1.tex
# [12/15/22 02:11:53] INFO     Animation 2 : Partial movie file written in                   ]8;id=472872;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=101392;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_1618324943_398543590.mp4'
# INFO:manim:Animation 2 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_1618324943_398543590.mp4'
#                     INFO     Animation 3 : Partial movie file written in                   ]8;id=124489;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=772002;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_2474512999_4143236013.mp4'
# INFO:manim:Animation 3 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_2474512999_4143236013.mp4'
#                     INFO     Writing This is a grid to media/Tex/f94d6db8f758e87f.tex        ]8;id=387197;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=35296;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
# INFO:manim:Writing This is a grid to media/Tex/f94d6db8f758e87f.tex
# [12/15/22 02:11:56] INFO     Animation 4 : Partial movie file written in                   ]8;id=717128;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=351379;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_3956397956_145925284.mp4'
# INFO:manim:Animation 4 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_3956397956_145925284.mp4'
# [12/15/22 02:11:57] INFO     Animation 5 : Partial movie file written in                   ]8;id=667456;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=702616;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_2474512999_3142345239.mp4'
# INFO:manim:Animation 5 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_2474512999_3142345239.mp4'
#                     INFO     Writing That was a non-linear function \\ applied to the grid   ]8;id=804871;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:]8;id=438754;file:///usr/local/lib/python3.8/dist-packages/manim/utils/tex_file_writing.py#97\97]8;;\
#                              to media/Tex/44a2f50ecf728444.tex
# INFO:manim:Writing That was a non-linear function \\ applied to the grid to media/Tex/44a2f50ecf728444.tex
# [12/15/22 02:12:03] INFO     Animation 6 : Partial movie file written in                   ]8;id=432440;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=988368;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_351914461_1681628507.mp4'
# INFO:manim:Animation 6 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_351914461_1681628507.mp4'
# [12/15/22 02:12:04] INFO     Animation 7 : Partial movie file written in                   ]8;id=793394;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=916531;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_2474512999_3983151766.mp4'
# INFO:manim:Animation 7 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_2474512999_3983151766.mp4'
# [12/15/22 02:12:06] INFO     Animation 8 : Partial movie file written in                   ]8;id=237832;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=464159;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_2906801638_348444065.mp4'
# INFO:manim:Animation 8 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_2906801638_348444065.mp4'
# [12/15/22 02:12:07] INFO     Animation 9 : Partial movie file written in                   ]8;id=575568;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=98133;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#527\527]8;;\
#                              '/content/media/videos/content/720p30/partial_movie_files/Ope
#                              ningManim/207390714_2474512999_534911450.mp4'
# INFO:manim:Animation 9 : Partial movie file written in '/content/media/videos/content/720p30/partial_movie_files/OpeningManim/207390714_2474512999_534911450.mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=196906;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=767451;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#617\617]8;;\
# INFO:manim:Combining to Movie file.
#                     INFO                                                                   ]8;id=406760;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=530965;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              '/content/media/videos/content/720p30/OpeningManim.mp4'
# INFO:manim:
# File ready at '/content/media/videos/content/720p30/OpeningManim.mp4'
#                     INFO     Rendered OpeningManim                                                     ]8;id=338559;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py\scene.py]8;;\:]8;id=702738;file:///usr/local/lib/python3.8/dist-packages/manim/scene/scene.py#241\241]8;;\
#                              Played 10 animations
# INFO:manim:Rendered OpeningManim
# Played 10 animations
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm -v WARNING UpdatersExample
#
# class UpdatersExample(Scene):
#     def construct(self):
#         decimal = DecimalNumber(
#             0,
#             show_ellipsis=True,
#             num_decimal_places=3,
#             include_sign=True,
#         )
#         square = Square().to_edge(UP)
#
#         decimal.add_updater(lambda d: d.next_to(square, RIGHT))
#         decimal.add_updater(lambda d: d.set_value(square.get_center()[1]))
#         self.add(square, decimal)
#         self.play(
#             square.animate.to_edge(DOWN),
#             rate_func=there_and_back,
#             run_time=5,
#         )
#         self.wait()
# Out:
# <video controls autoplay loop style="max-width: 20vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
